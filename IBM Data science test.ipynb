# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Christina Rodrigo**
# Graduate analyst - Barclays

# %% [markdown]
# *I am interested in Data Science because it cultivates my passion to understand and derive insights from raw data that prevails and is being collected everyday. I'm also passionate about business analysis perspective of transforming data to support and influence real-time decisions of an organization*

# %% [markdown]
# The below code is to display the rounded-off sum of a list of numbers, by storing it under variable 'a'. The sum is stored in variable 'S', and two functions round and sum are used.

# %%
a = [1,1/2,1/3]
S = round(sum(a))
print(S)
# Out:
# 2

# %% [markdown]
# [link text] (http://www.linkedin.com)
#
# **My skills**
#
# 1. Business Analytics
# 2. Investment Banking
# 3. Data management and analysis
# 4. Process automation
# 5. Software testing
#
# ~~never ever give up~~
